# %% [markdown]
# # Jupyter Notebook - Teste

# %% [markdown]
# Script teste para leitura do arquivo de carga do ONS com novo formato

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\TCC\\ScriptsPypsaBrazil\\open-brazilian-energy-data_atualizado\\load_time_series\\Simples Carga de Energia Dia Hora - Norte.csv",
                encoding='utf-16-le',
                sep='\t')
df = df.T
df.reset_index(drop=True, inplace=True)
df.index = range(len(df))
df.index.name = 'index'
df["Subsistema"] = df.iloc[:,1].iloc[0]
df.drop(0, inplace=True)
df.reset_index(drop=True, inplace=True)
df.rename(columns={df.columns[0]: 'Din Instante', df.columns[1]: 'Val Cargaenergiaconmwmed'}, inplace=True)
df['index'] = range(len(df))
reorder = ['index', 'Subsistema', 'Din Instante', 'Val Cargaenergiaconmwmed']
df = df[reorder].copy()
df['Val Cargaenergiaconmwmed'] = df['Val Cargaenergiaconmwmed'].str.replace('.', '').astype(float)
portuguese_month_abbreviations = {
    'jan': 'jan',
    'fev': 'feb',
    'mar': 'mar',
    'abr': 'apr',
    'mai': 'may',
    'jun': 'jun',
    'jul': 'jul',
    'ago': 'aug',
    'set': 'sep',
    'out': 'oct',
    'nov': 'nov',
    'dez': 'dec'
}

# Convert the 'Date_Column' to datetime format
df['Din Instante'] = pd.to_datetime(
    df['Din Instante'].replace(portuguese_month_abbreviations, regex=True),
    format='%d  de %b.  de %y - %H h',
)

# Format the 'Date_Column' in the desired format
df['Din Instante'] = df['Din Instante'].dt.strftime('%d.%m.%Y %H.%M.%S')


df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 32
#      16 portuguese_month_abbreviations = {
#      17     'jan.': 'jan',
#      18     'fev.': 'feb',
#    (...)
#      28     'dez.': 'dec'
#      29 }
#      31 # Convert the 'Date_Column' to datetime format
# ---> 32 df['Din Instante'] = pd.to_datetime(
#      33     df['Din Instante'].replace(portuguese_month_abbreviations, regex=True),
#      34     format='%d  de %b.  de %y - %H h',
#      35 )
#      37 # Format the 'Date_Column' in the desired format
#      38 df['Din Instante'] = df['Din Instante'].dt.strftime('%d.%m.%Y %H.%M.%S')
#
# File ~\AppData\Local\miniconda3\envs\esm-2023\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Local\miniconda3\envs\esm-2023\Lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File ~\AppData\Local\miniconda3\envs\esm-2023\Lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "1  de jan  de 23 - 00 h" doesn't match format "%d  de %b.  de %y - %H h", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df = pd.read_csv("C:\\TCC\\ScriptsPypsaBrazil\\open-brazilian-energy-data_atualizado\\load_time_series\\Simples Carga de Energia Dia Hora - Norte.csv",
                encoding='utf-16-le',
                sep='\t')

df = df.T
df.reset_index(drop=True, inplace=True)
df.index = range(len(df))
df.index.name = 'index'
df = df.drop(index=[0, 1, 2]).reset_index(drop=True)
df["Subsistema"] = df.iloc[:,1].iloc[0]
df.drop(0, inplace=True)
df.reset_index(drop=True, inplace=True)
df.rename(columns={df.columns[0]: 'Din Instante', df.columns[1]: 'Val Cargaenergiaconmwmed'}, inplace=True)
df['index'] = range(len(df))
reorder = ['index', 'Subsistema', 'Din Instante', 'Val Cargaenergiaconmwmed']
df = df[reorder].copy()
df['Val Cargaenergiaconmwmed'] = df['Val Cargaenergiaconmwmed'].str.replace('.', '').astype(float)
portuguese_month_abbreviations = {
    'jan.': 'jan',
    'fev.': 'feb',
    'mar.': 'mar',
    'abr.': 'apr',
    'mai.': 'may',
    'jun.': 'jun',
    'jul.': 'jul',
    'ago.': 'aug',
    'set.': 'sep',
    'out.': 'oct',
    'nov.': 'nov',
    'dez.': 'dec'
}

# Convert the 'Date_Column' to datetime format
df['Din Instante'] = pd.to_datetime(
    df['Din Instante'].replace(portuguese_month_abbreviations, regex=True),
    format='%d de %b de %y',
)

# Format the 'Date_Column' in the desired format
df['Din Instante'] = df['Din Instante'].dt.strftime('%d.%m.%Y %H.%M.%S')

df.head()
# Out:
#    index Subsistema         Din Instante  Val Enaarmazenavelmwmes
# 0      0      Norte  01.01.2000 00.00.00                  10393.0
# 1      1      Norte  02.01.2000 00.00.00                  10889.0
# 2      2      Norte  03.01.2000 00.00.00                  11227.0
# 3      3      Norte  04.01.2000 00.00.00                  11387.0
# 4      4      Norte  05.01.2000 00.00.00                  11517.0

# %%
df.describe()
# Out:
#              index  Val Enaarmazenavelmwmes
# count  8766.000000              8766.000000
# mean   4382.500000              7287.913073
# std    2530.670563              7253.951698
# min       0.000000               686.000000
# 25%    2191.250000              1787.000000
# 50%    4382.500000              4204.000000
# 75%    6573.750000             11074.000000
# max    8765.000000             39297.000000
