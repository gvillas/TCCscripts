# %% [markdown]
# # Script teste para agrupamento de dados de rede

# %% [markdown]
# O objetivo do script é possibilitar que dados de capacidade de interconexão sejam agregados em subsistemas. Para isso, é feito a leitura do arquivo gerado pelos scripts do pypsa-brazil

# %%
import pandas as pd
import numpy as np

# %%
path = "C:\\TCC\\ScriptsPypsaBrazil\\open-brazilian-energy-data_atualizado\\grid\\results\\EPEWebmap_equivalent_grid_aggregate_by_state_operation_and_planed.csv"
grid = pd.read_csv(path)
grid.head()
# Out:
#    Unnamed: 0 node0 node1  transfer_capacity  efficiency  \
# 0           0    AC    RO         694.424749    0.997181
# 1           1    AL    BA        9740.762028    0.998153
# 2           2    AL    PE        6690.456467    0.997816
# 3           3    AL    SE        9677.314272    0.998663
# 4           4    AM    PA        2650.803484    0.999133
#
#                                                 name      length carrier
# 0  LT 230 kV Abunã - Rio Branco I, C2_LT 230 kV A...  304.879878      ac
# 1  LT 230 kV Paulo Afonso III - UHE Paulo Afonso ...   31.629925      ac
# 2  LT 230 kV Garanhuns II - Paulo Afonso III C3_L...  134.432276      ac
# 3  LT 500 kV UHE Xingó - Xingó C4_LT 230 kV Paulo...   69.919940      ac
# 4  LT 500 kV Oriximiná - Silves, C1_LT 500 kV Ori...  255.321517      ac

# %%
regiao_estado ={'PA': 'NORTE',
                'TO': 'NORTE',
                'MA': 'NORTE',
                'AP': 'NORTE',
                'AM': 'NORTE',
                'RR': 'NORTE',
                'PI': 'NORDESTE',
                'CE': 'NORDESTE',
                'RN': 'NORDESTE',
                'PB': 'NORDESTE',
                'PE': 'NORDESTE',
                'AL': 'NORDESTE',
                'SE': 'NORDESTE',
                'BA': 'NORDESTE',
                'ES': 'SUDESTE',
                'RJ': 'SUDESTE',
                'MG': 'SUDESTE',
                'SP': 'SUDESTE',
                'GO': 'SUDESTE',
                'DF': 'SUDESTE',
                'MT': 'SUDESTE',
                'AC': 'SUDESTE',
                'RO': 'SUDESTE',
                'MS': 'SUDESTE',
                'RS': 'SUL',
                'SC': 'SUL',
                'PR': 'SUL',
                'ARG': 'ARGENTINA',
                'PRY': 'PARAGUAI',
                'VEN': 'VENEZUELA',
                'URY': 'URUGUAI'}

print(regiao_estado)
# Out:
# {'PA': 'NORTE', 'TO': 'NORTE', 'MA': 'NORTE', 'AP': 'NORTE', 'AM': 'NORTE', 'RR': 'NORTE', 'PI': 'NORDESTE', 'CE': 'NORDESTE', 'RN': 'NORDESTE', 'PB': 'NORDESTE', 'PE': 'NORDESTE', 'AL': 'NORDESTE', 'SE': 'NORDESTE', 'BA': 'NORDESTE', 'ES': 'SUDESTE', 'RJ': 'SUDESTE', 'MG': 'SUDESTE', 'SP': 'SUDESTE', 'GO': 'SUDESTE', 'DF': 'SUDESTE', 'MT': 'SUDESTE', 'AC': 'SUDESTE', 'RO': 'SUDESTE', 'MS': 'SUDESTE', 'RS': 'SUL', 'SC': 'SUL', 'PR': 'SUL', 'ARG': 'ARGENTINA', 'PRY': 'PARAGUAI', 'VEN': 'VENEZUELA', 'URY': 'URUGUAI'}

# %%
grid = grid.drop(columns=["name", "length", "carrier"])
grid.head()
# Out:
#    Unnamed: 0 node0 node1  transfer_capacity  efficiency
# 0           0    AC    RO         694.424749    0.997181
# 1           1    AL    BA        9740.762028    0.998153
# 2           2    AL    PE        6690.456467    0.997816
# 3           3    AL    SE        9677.314272    0.998663
# 4           4    AM    PA        2650.803484    0.999133

# %%
grid["regiao0"] = grid["node0"].map(regiao_estado)
grid["regiao1"] = grid["node1"].map(regiao_estado)
grid.head()
# Out:
#    Unnamed: 0 node0 node1  transfer_capacity  efficiency   regiao0   regiao1
# 0           0    AC    RO         694.424749    0.997181   SUDESTE   SUDESTE
# 1           1    AL    BA        9740.762028    0.998153  NORDESTE  NORDESTE
# 2           2    AL    PE        6690.456467    0.997816  NORDESTE  NORDESTE
# 3           3    AL    SE        9677.314272    0.998663  NORDESTE  NORDESTE
# 4           4    AM    PA        2650.803484    0.999133     NORTE     NORTE

# %%
regioes_brasil = ['SUDESTE', 'SUL', 'NORDESTE', 'NORTE']
grid_subsistema = pd.DataFrame(columns = ['regiao0', 'regiao1', 'transfer_capacity', 'efficiency'])
for regiao0 in regioes_brasil:
    regioes_total = ['SUDESTE', 'SUL', 'NORDESTE', 'NORTE', 'ARGENTINA','PARAGUAI','VENEZUELA', 'URUGUAI']
    regioes_total.remove(regiao0)
    for regiao1 in regioes_total:
        grid_regiao = grid[(grid['regiao0'] == regiao0 & grid['regiao1'] == regiao1) or
                           (grid['regiao0'] == regiao1 & grid['regiao1'] == regiao0)]
        if not grid_regiao.empty:
            transfer_capacity = grid_regiao['transfer_capacity'].sum()
            efficiency = np.average(df['efficiency'], weights=df['transfer_capacity'])
            grid_subsistema = grid_subsistema.append({'regiao0': regiao0,
                                                      'regiao1': regiao1,
                                                      'transfer_capacity': transfer_capacity,
                                                      'efficiency': efficiency})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\envs\esm-2023\Lib\site-packages\pandas\core\ops\array_ops.py:364, in na_logical_op(x, y, op)
#     355 try:
#     356     # For exposition, write:
#     357     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     362     # Then Cases where this goes through without raising include:
#     363     #  (xint or xbool) and (yint or bool)
# --> 364     result = op(x, y)
#     365 except TypeError:
#
# File ~\AppData\Local\miniconda3\envs\esm-2023\Lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dict_test = {'regiao0': 'SUDESTE','regiao1': 'SUL','transfer_capacity': 10,'efficiency': 1}
dict_test_df = pd.DataFrame(dict_test, index=[0])
dict_test_df.head()
# Out:
#    regiao0 regiao1  transfer_capacity  efficiency
# 0  SUDESTE     SUL                 10           1

# %%
test = pd.DataFrame(columns = ['regiao0', 'regiao1', 'transfer_capacity', 'efficiency'])
dict_test = {'regiao0': 'SUDESTE','regiao1': 'SUL','transfer_capacity': 10,'efficiency': 1}
pd.concat([test, pd.DataFrame(dict_test, index=[0])])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 test = pd.DataFrame(columns = ['regiao0', 'regiao1', 'transfer_capacity', 'efficiency'])
#       2 dict_test = {'regiao0': 'SUDESTE','regiao1': 'SUL','transfer_capacity': 10,'efficiency': 1}
# ----> 3 pd.concat([test, pd.DataFrame.from_dict(dict_test)], ignore_index=True)
#
# File ~\AppData\Local\miniconda3\envs\esm-2023\Lib\site-packages\pandas\core\frame.py:1816, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1810     raise ValueError(
#    1811         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1812         f"Got '{orient}' instead"
#    1813     )
#    1815 if orient != "tight":
# -> 1816     return cls(data, index=index, columns=columns, dtype=dtype)
#    1817 else:
#    1818     realdata = data["data"]
#
# ...
